# %% [markdown]
# # Python Practice Set — Extended Topics (Beginner / Intermediate / Advanced)
#
# ### Instructions
#
# 1. Function/class skeletons are provided below.
# 2. **Do not change the function/class name or input-output format.**
# 3. Write your logic only where indicated by `# YOUR LOGIC HERE`.
# 4. Every topic has exactly **3 questions**: Beginner → Intermediate → Advanced. Try them in that order.
# 5. Run each cell and compare your result with the Expected Output shown in the question.
# 6. Try to solve without looking back at your notes first — that's how it sticks.
# 7. Solutions are NOT included in this notebook, so you can self-check honestly.

# %% [markdown]
# ---
#
# ## Ch-1: Introduction of Python

# %% [markdown]
# ### Beginner
#
# Write a function `greet_user(name)` that returns the string:
# `"Hello, <name>! Welcome to Python."`
#
# **Example**
# Input: `name = "Asha"`
# Expected Output: `Hello, Asha! Welcome to Python.`

# %%
def greet_user(name):
    # YOUR LOGIC HERE
     
    result= "Hello, %s ! Welcome to Python" %name
    return result
    pass


# Test input
name = "Asha"
result = greet_user(name)
print(result)
# Out:
# Hello, Asha ! Welcome to Python

# %% [markdown]
# ### Intermediate
#
# Write a function `describe_variable(value)` that returns a string in the form
# `"<value> is of type <type_name>"`, where `<type_name>` is the Python type name
# (e.g. `int`, `str`, `float`, `list`).
#
# **Example**
# Input: `value = 42`
# Expected Output: `42 is of type int`

# %%
def describe_variable(value):
    # YOUR LOGIC HERE
    # result= "%d is of type %s "% (value,type(value)) 
    # return result
    print (f"{value} is of type {type(value)}")


# Test input
value = 42
result = describe_variable(value)
# Out:
# 42 is of type <class 'int'>

# %% [markdown]
# ### Advanced
#
# Write a function `count_python_keywords(code_snippet)` that splits a snippet
# of code on whitespace and returns how many of the resulting tokens are actual
# Python keywords, using the `keyword` module (`keyword.iskeyword`).
#
# **Example**
# Input: `"if x return else for y"`
# Expected Output: `4` (`if`, `return`, `else`, `for` are keywords)

# %%
import keyword

def count_python_keywords(code_snippet):
    # YOUR LOGIC HERE
    count=0
    d=[]
    for i in code_snippet.split():
        if keyword.iskeyword(i):
            count=count+1
            print(i)
            d.append(i)

    
    return count,d
   
    pass


# Test input
code_snippet = "if x return else for y"
result = count_python_keywords(code_snippet)
print(result)
# Out:
# if
# return
# else
# for
# (4, ['if', 'return', 'else', 'for'])

# %% [markdown]
# ---
#
# ## Ch-2: Expressions & Variables

# %% [markdown]
# ### Beginner
#
# Write a function `swap_values(a, b)` that swaps `a` and `b` **without using a
# temporary third variable**, and returns them as a tuple `(new_a, new_b)`.
#
# **Example**
# Input: `a = 5, b = 9`
# Expected Output: `(9, 5)`

# %%
def swap_values(a, b):
    # YOUR LOGIC HERE
    # a,b=b,a
    # print(a,b)
    # pass
    temp=a
    a=b
    b=temp
    print(a,b)

# Test input
a, b = 5, 9
result = swap_values(a, b)
print(result)
# Out:
# 9 5
# None

# %% [markdown]
# ### Intermediate
#
# Write a function `circle_stats(radius)` that returns a tuple
# `(area, circumference)`, both rounded to 2 decimal places. Use `3.14159` for pi.
#
# **Example**
# Input: `radius = 4`
# Expected Output: `(50.27, 25.13)`

# %%
def circle_stats(radius):
    # YOUR LOGIC HERE
    return f"{3.14159*radius**2:.2f}",f"{ 2*3.14159*radius:.2f}"
    pass


# Test input
radius = 4
result = circle_stats(radius)
print(result)
# Out:
# ('50.27', '25.13')

# %% [markdown]
# ### Advanced
#
# Write a function `solve_expression(a, b, c)` that evaluates the expression
# `(a + b) * c - a ** 2 // b` and returns the integer result, respecting Python's
# operator precedence (no extra parentheses beyond what's shown).
#
# **Example**
# Input: `a = 4, b = 3, c = 5`
# Expected Output: `29`

# %%
def solve_expression(a, b, c):
    # YOUR LOGIC HERE
    return f"{(a + b) * c - a ** 2 // b}"
    pass


# Test input
a, b, c = 4, 3, 5
result = solve_expression(a, b, c)
print(result)
# Out:
# 30

# %% [markdown]
# ---
#
# ## Ch-3: Conditions, Loops and Iteration

# %% [markdown]
# ### Beginner
#
# Write a function `fizzbuzz(n)` that returns a list of strings for numbers 1 to n:
# - Multiples of 3 → `"Fizz"`
# - Multiples of 5 → `"Buzz"`
# - Multiples of both → `"FizzBuzz"`
# - Otherwise → the number as a string
#
# **Example**
# Input: `n = 15`
# Expected Output: `['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']`

# %%
def fizzbuzz(n):
    # YOUR LOGIC HERE
    # f=[]
    # for i in range (1,n+1):
    #    f.append(str(i))
    # print(f) 

    # for j in range(len(f)):
    #     if  int(f[j])%3==0 and int(f[j])%5==0:
    #         f[j]=f[j].replace(f[j],"FizzBuzz")
    #     elif int(f[j])%5 ==0:
    #         f[j]=f[j].replace(f[j],"Buzz")
    #     elif int(f[j])%3==0:
    #         f[j]=f[j].replace(f[j],"Fizz")
        
    # return f    
    f=[]    
    for i in range(1,n+1):
        if i%3==0 and i%5==0:
            r="FizzBuzz"
            f.append(r)
        elif i%3==0:
            r="Fizz"
            f.append(r)
        elif i%5==0:
            r="Buzz"
            f.append(r)
        else:
            s=str(i)
            f.append(s)
    return f              

    pass


# Test input
n = 15
result = fizzbuzz(n)
print(result)
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %% [markdown]
# ### Intermediate
#
# Write a function `sum_of_digits(number)` that returns the sum of the digits of a
# positive integer, using a `while` loop.
#
# **Example**
# Input: `number = 4931`
# Expected Output: `17`

# %%
def sum_of_digits(number):
    # YOUR LOGIC HERE
    f=[]
    while number>0:
        digit=number%10
        f.append(digit)
        number=number//10
    t=0
    for i in f:
        t=t+i
    return t
    pass


# Test input
number = 4931
result = sum_of_digits(number)
print(result)
# Out:
# 17

# %% [markdown]
# ### Advanced
#
# Write a function `pythagorean_triplets(limit)` that returns a list of all
# Pythagorean triplets `(a, b, c)` with `a < b < c <= limit` such that
# `a**2 + b**2 == c**2`, using nested loops.
#
# **Example**
# Input: `limit = 15`
# Expected Output: `[(3, 4, 5), (5, 12, 13), (6, 8, 10), (9, 12, 15)]`

# %%
def pythagorean_triplets(limit):
    # YOUR LOGIC HERE
    result=[]
    for a in range (1,limit+1):
        for b in range (a+1,limit+1):
            for c in range(b+1,limit+1):

                if a**2 + b**2 == c**2:
                    result.append((a,b,c))

    return result                 
    pass


# Test input
limit = 15
result = pythagorean_triplets(limit)
print(result)
# Out:
# [(3, 4, 5), (5, 12, 13), (6, 8, 10), (9, 12, 15)]

# %% [markdown]
# ---
#
# ## Ch-4: Functions & Libraries

# %% [markdown]
# ### Beginner
#
# Write a function `factorial_using_math(n)` that returns `n!` using `math.factorial`.
#
# **Example**
# Input: `n = 6`
# Expected Output: `720`

# %%
import math

def factorial_using_math(n):
    # YOUR LOGIC HERE
    print(math.factorial(n))
    r=1
    for i in range(1,n+1):
        r=r*i
    return r    

    pass


# Test input
n = 6
result = factorial_using_math(n)
print(result)
# Out:
# 720
# 720

# %% [markdown]
# ### Intermediate
#
# Write a function `calculate_discounted_price(price, discount=10)` that returns
# the price after applying a percentage discount, rounded to 2 decimals. `discount`
# should default to 10 if not given.
#
# **Example**
# Input: `price = 200` (no discount given)
# Expected Output: `180.0`

# %%
def calculate_discounted_price(price, discount=10):
    # YOUR LOGIC HERE
    i=price*(10/100)
    upd_price=price-i
    print (upd_price)
    pass


# Test input
price = 200
result = calculate_discounted_price(price)
print(result)
# Out:
# 180.0
# None

# %% [markdown]
# ### Advanced
#
# Using the `itertools` library, write a function `all_pairs_sum(numbers, target)`
# that returns a list of all unique pairs `(a, b)` from `numbers` (using
# `itertools.combinations`, so no repeats) whose sum equals `target`.
#
# **Example**
# Input: `numbers = [2, 4, 3, 5, 7, 8], target = 9`
# Expected Output: `[(2, 7), (4, 5)]`

# %%
import itertools

def all_pairs_sum(numbers, target):
    # YOUR LOGIC HERE
    result=[]
    n=len(numbers)
    for i in range (n):
        for j in range(i+1,n):
            if numbers[i]+numbers[j]==target:
                result.append((numbers[i],numbers[j]))
    return result


    pass


# Test input
numbers = [2, 4, 3, 5, 7, 8]
target = 9
result = all_pairs_sum(numbers, target)
print(result)
# Out:
# [(2, 7), (4, 5)]

# %% [markdown]
# ---
#
# ## Ch-5: Data Structure and File I/O

# %% [markdown]
# ### Beginner
#
# Given a list of dictionaries, each with `"name"` and `"salary"`, write a function
# `highest_paid(employees)` that returns the name of the employee with the highest
# salary.
#
# **Example**
# Input: `[{"name": "Ravi", "salary": 45000}, {"name": "Meena", "salary": 62000}, {"name": "Zoya", "salary": 58000}]`
# Expected Output: `Meena`

# %%
def highest_paid(employees):
    # YOUR LOGIC HERE
    h_salary=0
    H_S_name=""
    for employee in employees:

         if employee["salary"]>h_salary:
            h_salary=employee["salary"]
            H_S_name=employee["name"]
    return H_S_name

    pass


# Test input
employees = [
    {"name": "Ravi", "salary": 45000},
    {"name": "Meena", "salary": 62000},
    {"name": "Zoya", "salary": 58000},
]
result = highest_paid(employees)
print(result)
# Out:
# Meena

# %% [markdown]
# ### Intermediate
#
# Write a function `save_and_load_names(names, filepath)` that:
# 1. Writes each name in `names` to the file at `filepath`, one per line.
# 2. Reads the file back and returns the names as a list (stripped of whitespace).
#
# **Example**
# Input: `names = ["Alex", "Sam", "Priya"], filepath = "names.txt"`
# Expected Output: `['Alex', 'Sam', 'Priya']`

# %%
def save_and_load_names(names, filepath):
    # YOUR LOGIC HERE
    result=[]
    with open (filepath,"w") as file:
        for name in names:
            file.write(name +"\n")

    with open (filepath, "r") as file:
        for line in file:
            result.append(line.strip())

    return result                
    pass


# Test input
names = ["Alex", "Sam", "Priya"]
result = save_and_load_names(names, "names.txt")
print(result)
# Out:
# ['Alex', 'Sam', 'Priya']

# %% [markdown]
# ### Advanced
#
# Given a list of employee dicts with `"name"`, `"department"`, and `"salary"`,
# write a function `group_by_department(employees)` that returns a dictionary
# mapping each department to a tuple `(list_of_names, total_salary)`.
#
# **Example**
# Input: `[{"name": "Ravi", "department": "IT", "salary": 40000}, {"name": "Meena", "department": "HR", "salary": 30000}, {"name": "Zoya", "department": "IT", "salary": 50000}]`
# Expected Output: `{'IT': (['Ravi', 'Zoya'], 90000), 'HR': (['Meena'], 30000)}`

# %%
def group_by_department(employees):
    # YOUR LOGIC HERE
    result={}
    for emp in employees:
        dep=emp["department"]
        name=emp["name"]
        salary=emp["salary"]

        if dep not in result:
            result[dep]=([],0)
        result[dep][0].append(name)

        result[dep]=(
            result[dep][0],
            result[dep][1] + salary
        ) 
    return result       
    pass


# Test input
employees = [
    {"name": "Ravi", "department": "IT", "salary": 40000},
    {"name": "Meena", "department": "HR", "salary": 30000},
    {"name": "Zoya", "department": "IT", "salary": 50000},
]
result = group_by_department(employees)
print(result)
# Out:
# {'IT': (['Ravi', 'Zoya'], 90000), 'HR': (['Meena'], 30000)}

# %% [markdown]
# ---
#
# ## Ch-6: Network & Socket IO

# %% [markdown]
# ### Beginner
#
# Imagine a raw HTTP-style header block received over a socket, like
# `"Host: example.com\nContent-Type: json\n"`. Write a function
# `parse_headers(raw)` that returns a dictionary of header-name to header-value.
# (No real socket connection needed — just process the string.)
#
# **Example**
# Input: `"Host: example.com\nContent-Type: json"`
# Expected Output: `{'Host': 'example.com', 'Content-Type': 'json'}`

# %%
def parse_headers(raw):
    # YOUR LOGIC HERE
    pass


# Test input
raw = "Host: example.com\nContent-Type: json"
result = parse_headers(raw)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `echo_response(message)` that simulates what a simple echo
# server would send back: the message uppercased, prefixed with `"ECHO: "`.
#
# **Example**
# Input: `message = "ping"`
# Expected Output: `ECHO: PING`

# %%
def echo_response(message):
    # YOUR LOGIC HERE
    pass


# Test input
message = "ping"
result = echo_response(message)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `parse_request_line(request_line)` that parses a raw HTTP
# request line like `"GET /users HTTP/1.1"` and returns a dict
# `{"method": ..., "path": ..., "version": ...}`.
#
# **Example**
# Input: `"GET /users HTTP/1.1"`
# Expected Output: `{'method': 'GET', 'path': '/users', 'version': 'HTTP/1.1'}`

# %%
def parse_request_line(request_line):
    # YOUR LOGIC HERE
    pass


# Test input
request_line = "GET /users HTTP/1.1"
result = parse_request_line(request_line)
print(result)

# %% [markdown]
# ---
#
# ## Ch-7: OOP Concepts

# %% [markdown]
# ### Beginner
#
# Complete the `BankAccount` class with `deposit(amount)` and `withdraw(amount)`
# methods. `withdraw` should refuse (return `"Insufficient funds"`) if the amount
# exceeds the balance; otherwise both methods return the new balance.
#
# **Example**
# Input: `acc = BankAccount(100); acc.deposit(50); acc.withdraw(30)`
# Expected Output: `120`

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.balance = balance

    def deposit(self, amount):
        # YOUR LOGIC HERE
        self.balance=self.balance + amount
        return self.balance
        pass

    def withdraw(self, amount):
        # YOUR LOGIC HERE
        if amount > self.balance:
            return "insufficient funds!!..."
        else:
            self.balance=self.balance-amount
            return self.balance    
        pass


# Test input
acc = BankAccount(100)
acc.deposit(50)
result = acc.withdraw(30)
print(result)
# Out:
# 120

# %% [markdown]
# ### Intermediate
#
# Complete the `Employee` class method `calculate_bonus()`:
# - 10+ years → 20% of salary
# - 5–9 years → 10% of salary
# - Under 5 years → 5% of salary
#
# **Example**
# Input: `Employee("Ravi", 50000, 6)`
# Expected Output: `5000.0`

# %%
class Employee:
    def __init__(self, name, salary, years):
        self.name = name
        self.salary = salary
        self.years = years

    def calculate_bonus(self):
        # YOUR LOGIC HERE
        if self.years >10:
            return self.salary*0.20
        elif self.years < 9:
            return self.salary*0.10
        elif self.years < 5:
            return self.salary*0.05


    


# Test input
emp = Employee("Ravi", 50000, 6)
result = emp.calculate_bonus()
print(result)
# Out:
# 5000.0

# %% [markdown]
# ### Advanced
#
# Complete the `InventoryItem` class so that a **class variable** `total_items`
# tracks how many items have been created across all instances. Add a
# **class method** `total_count()` that returns this total.
#
# **Example**
# Input: `InventoryItem("Pen"); InventoryItem("Notebook"); InventoryItem.total_count()`
# Expected Output: `2`

# %%
class InventoryItem:
    total_items = 0

    def __init__(self, name):
        self.name = name
        # YOUR LOGIC HERE (update the class variable)
        InventoryItem.total_items +=1

    @classmethod
    def total_count(cls):
        # YOUR LOGIC HERE
        return cls.total_items
        pass


# Test input
InventoryItem("Pen")
InventoryItem("Notebook")
result = InventoryItem.total_count()
print(result)
# Out:
# 2

# %% [markdown]
# ---
#
# ## Ch-8: Web Services

# %% [markdown]
# ### Beginner
#
# Write a function `build_query_string(params)` that takes a dict of parameters
# and returns a URL query string like `"key1=value1&key2=value2"`.
#
# **Example**
# Input: `{"q": "python", "page": 2}`
# Expected Output: `q=python&page=2`

# %%
def build_query_string(params):
    # YOUR LOGIC HERE
    pass


# Test input
params = {"q": "python", "page": 2}
result = build_query_string(params)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `make_response(data, status_code)` that returns a dictionary
# shaped like a REST API response: `{"status": status_code, "success": <bool>, "data": data}`,
# where `success` is `True` if `status_code` is between 200 and 299.
#
# **Example**
# Input: `data = {"id": 1}, status_code = 201`
# Expected Output: `{'status': 201, 'success': True, 'data': {'id': 1}}`

# %%
def make_response(data, status_code):
    # YOUR LOGIC HERE
    pass


# Test input
data = {"id": 1}
status_code = 201
result = make_response(data, status_code)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `paginate_results(items, page, page_size)` that returns a dict
# `{"items": <the slice for that page>, "page": page, "total_pages": <total>}`.
# Pages are 1-indexed.
#
# **Example**
# Input: `items = list(range(1, 11)), page = 2, page_size = 4`
# Expected Output: `{'items': [5, 6, 7, 8], 'page': 2, 'total_pages': 3}`

# %%
def paginate_results(items, page, page_size):
    # YOUR LOGIC HERE
    pass


# Test input
items = list(range(1, 11))
page, page_size = 2, 4
result = paginate_results(items, page, page_size)
print(result)

# %% [markdown]
# ---
#
# ## Class-Object

# %% [markdown]
# ### Beginner
#
# Complete the `Book` class with a `describe()` method that returns
# `"<title> by <author>"`.
#
# **Example**
# Input: `Book("1984", "George Orwell")`
# Expected Output: `1984 by George Orwell`

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def describe(self):
        # YOUR LOGIC HERE

        return self.title + " by " + self.author 
        pass


# Test input
b = Book("1984", "George Orwell")
result = b.describe()
print(result)
# Out:
# 1984 by George Orwell

# %% [markdown]
# ### Intermediate
#
# Complete the `Rectangle` class with `area()` and `perimeter()` methods.
#
# **Example**
# Input: `Rectangle(4, 6)`
# Expected Output: `area = 24, perimeter = 20`

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        # YOUR LOGIC HERE
        pass

    def perimeter(self):
        # YOUR LOGIC HERE
        pass


# Test input
r = Rectangle(4, 6)
print("area =", r.area(), ", perimeter =", r.perimeter())

# %% [markdown]
# ### Advanced
#
# Complete the `Student` class, which stores a list of `grades`. Add
# `average_grade()` (rounded to 2 decimals) and `is_passing()` (returns `True`
# if the average is 40 or above).
#
# **Example**
# Input: `Student("Zoya", [55, 40, 62, 38])`
# Expected Output: `average = 48.75, passing = True`

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        # YOUR LOGIC HERE
        pass

    def is_passing(self):
        # YOUR LOGIC HERE
        pass


# Test input
s = Student("Zoya", [55, 40, 62, 38])
print("average =", s.average_grade(), ", passing =", s.is_passing())

# %% [markdown]
# ---
#
# ## Collections

# %% [markdown]
# ### Beginner
#
# Write a function `remove_duplicates(items)` that returns a list with duplicates
# removed, preserving the original order.
#
# **Example**
# Input: `[1, 2, 2, 3, 1, 4]`
# Expected Output: `[1, 2, 3, 4]`

# %%
def remove_duplicates(items):
    # YOUR LOGIC HERE
    pass


# Test input
items = [1, 2, 2, 3, 1, 4]
result = remove_duplicates(items)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `common_elements(list1, list2)` that returns a **sorted list**
# of elements common to both lists, using set operations.
#
# **Example**
# Input: `[1, 2, 3, 4], [3, 4, 5, 6]`
# Expected Output: `[3, 4]`

# %%
def common_elements(list1, list2):
    # YOUR LOGIC HERE
    pass


# Test input
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5, 6]
result = common_elements(list1, list2)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `most_frequent_element(items)` that returns the element that
# appears most often in the list. If there's a tie, return whichever of the
# tied elements occurs **first** in the list.
#
# **Example**
# Input: `[4, 2, 4, 1, 2, 4, 1]`
# Expected Output: `4`

# %%
def most_frequent_element(items):
    # YOUR LOGIC HERE
    pass


# Test input
items = [4, 2, 4, 1, 2, 4, 1]
result = most_frequent_element(items)
print(result)

# %% [markdown]
# ---
#
# ## Collections Functions

# %% [markdown]
# ### Beginner
#
# Write a function `square_even_numbers(numbers)` that uses `filter` to keep even
# numbers and `map` to square them, returning the result as a list.
#
# **Example**
# Input: `[1, 2, 3, 4, 5, 6]`
# Expected Output: `[4, 16, 36]`

# %%
def square_even_numbers(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [1, 2, 3, 4, 5, 6]
result = square_even_numbers(numbers)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `sort_by_second(pairs)` that sorts a list of tuples by the
# **second** element of each tuple, using `sorted()` with a `key`.
#
# **Example**
# Input: `[(1, 5), (2, 2), (3, 8)]`
# Expected Output: `[(2, 2), (1, 5), (3, 8)]`

# %%
def sort_by_second(pairs):
    # YOUR LOGIC HERE
    pass


# Test input
pairs = [(1, 5), (2, 2), (3, 8)]
result = sort_by_second(pairs)
print(result)

# %% [markdown]
# ### Advanced
#
# Using `functools.reduce` together with `filter`, write a function
# `product_of_nonzero(numbers)` that filters out any zeros from the list, then
# returns the product of the remaining numbers.
#
# **Example**
# Input: `[2, 0, 3, 4, 0, 5]`
# Expected Output: `120`

# %%
from functools import reduce

def product_of_nonzero(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [2, 0, 3, 4, 0, 5]
result = product_of_nonzero(numbers)
print(result)

# %% [markdown]
# ---
#
# ## Conditions & Loops

# %% [markdown]
# ### Beginner
#
# Write a function `classify_triangle(a, b, c)` that returns `"Equilateral"`,
# `"Isosceles"`, or `"Scalene"` based on the three side lengths.
#
# **Example**
# Input: `a = 5, b = 5, c = 8`
# Expected Output: `Isosceles`

# %%
def classify_triangle(a, b, c):
    # YOUR LOGIC HERE
    pass


# Test input
a, b, c = 5, 5, 8
result = classify_triangle(a, b, c)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `count_vowels(text)` that returns the number of vowels
# (a, e, i, o, u — case-insensitive) in a string, using a loop.
#
# **Example**
# Input: `"Hello World"`
# Expected Output: `3`

# %%
def count_vowels(text):
    # YOUR LOGIC HERE
    pass


# Test input
text = "Hello World"
result = count_vowels(text)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `longest_increasing_run(numbers)` that returns the length of
# the longest run of **strictly increasing consecutive** numbers in the list.
#
# **Example**
# Input: `[1, 2, 3, 2, 4, 5, 6, 7, 1]`
# Expected Output: `4` (the run `4, 5, 6, 7`)

# %%
def longest_increasing_run(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [1, 2, 3, 2, 4, 5, 6, 7, 1]
result = longest_increasing_run(numbers)
print(result)

# %% [markdown]
# ---
#
# ## Database Connectivity

# %% [markdown]
# ### Beginner
#
# Write a function `build_insert_sql(table, row)` that takes a table name and a
# dict of column-to-value, and returns an SQL INSERT string:
# `"INSERT INTO <table> (col1, col2) VALUES ('val1', 'val2')"`.
# (Treat all values as strings for simplicity.)
#
# **Example**
# Input: `table = "users", row = {"name": "Sam", "city": "Pune"}`
# Expected Output: `INSERT INTO users (name, city) VALUES ('Sam', 'Pune')`

# %%
def build_insert_sql(table, row):
    # YOUR LOGIC HERE
    pass


# Test input
table = "users"
row = {"name": "Sam", "city": "Pune"}
result = build_insert_sql(table, row)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `is_valid_connection_string(conn_str)` that returns `True` if
# the string matches the pattern `"host:port/dbname"` (host and dbname are
# non-empty, port is numeric), else `False`.
#
# **Example**
# Input: `"localhost:5432/mydb"`
# Expected Output: `True`

# %%
def is_valid_connection_string(conn_str):
    # YOUR LOGIC HERE
    pass


# Test input
conn_str = "localhost:5432/mydb"
result = is_valid_connection_string(conn_str)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `build_update_sql(table, updates, condition)` that returns an
# SQL UPDATE string: `"UPDATE <table> SET col1 = 'val1', col2 = 'val2' WHERE <condition>"`.
#
# **Example**
# Input: `table = "users", updates = {"city": "Mumbai", "active": "yes"}, condition = "id = 5"`
# Expected Output: `UPDATE users SET city = 'Mumbai', active = 'yes' WHERE id = 5`

# %%
def build_update_sql(table, updates, condition):
    # YOUR LOGIC HERE
    pass


# Test input
table = "users"
updates = {"city": "Mumbai", "active": "yes"}
condition = "id = 5"
result = build_update_sql(table, updates, condition)
print(result)

# %% [markdown]
# ---
#
# ## Encapsulation-Polymorphism

# %% [markdown]
# ### Beginner
#
# Complete the `Person` class so that `age` is stored as a private attribute
# (`self.__age`), with `get_age()` returning it and `set_age(value)` only updating
# it if `value >= 0` (otherwise ignore the update silently).
#
# **Example**
# Input: `p = Person(30); p.set_age(-5); p.get_age()`
# Expected Output: `30`

# %%
class Person:
    def __init__(self, age):
        self.__age = age

    def get_age(self):
        # YOUR LOGIC HERE
        pass

    def set_age(self, value):
        # YOUR LOGIC HERE
        pass


# Test input
p = Person(30)
p.set_age(-5)
result = p.get_age()
print(result)

# %% [markdown]
# ### Intermediate
#
# Complete the `Dog` and `Cat` classes so each has a `make_sound()` method
# returning `"Woof"` and `"Meow"` respectively. Then write `all_sounds(animals)`
# that returns a list of sounds by calling `make_sound()` on each object.
#
# **Example**
# Input: `[Dog(), Cat(), Dog()]`
# Expected Output: `['Woof', 'Meow', 'Woof']`

# %%
class Dog:
    def make_sound(self):
        # YOUR LOGIC HERE
        pass


class Cat:
    def make_sound(self):
        # YOUR LOGIC HERE
        pass


def all_sounds(animals):
    # YOUR LOGIC HERE
    pass


# Test input
animals = [Dog(), Cat(), Dog()]
result = all_sounds(animals)
print(result)

# %% [markdown]
# ### Advanced
#
# Complete the `Temperature` class which stores celsius privately
# (`self.__celsius`). Add a `fahrenheit` **property** (computed as
# `celsius * 9/5 + 32`) with a **setter** that converts an incoming Fahrenheit
# value back to Celsius and stores it.
#
# **Example**
# Input: `t = Temperature(0); t.fahrenheit` → `32.0`; then `t.fahrenheit = 212` → celsius becomes `100.0`

# %%
class Temperature:
    def __init__(self, celsius=0):
        self.__celsius = celsius

    @property
    def fahrenheit(self):
        # YOUR LOGIC HERE
        pass

    @fahrenheit.setter
    def fahrenheit(self, value):
        # YOUR LOGIC HERE
        pass


# Test input
t = Temperature(0)
print(t.fahrenheit)
t.fahrenheit = 212
print(t.fahrenheit)

# %% [markdown]
# ---
#
# ## Exception Handling

# %% [markdown]
# ### Beginner
#
# Write a function `safe_divide(a, b)` that returns `a / b`, but returns the
# string `"Cannot divide by zero"` instead of raising an error when `b` is 0.
#
# **Example**
# Input: `a = 10, b = 0`
# Expected Output: `Cannot divide by zero`

# %%
def safe_divide(a, b):
    # YOUR LOGIC HERE
    pass


# Test input
a, b = 10, 0
result = safe_divide(a, b)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `validate_age(age)` that raises a `ValueError` if `age < 0`,
# catches it internally, and returns the string `"Invalid age: <age>"` in that
# case; otherwise it returns `"Valid age: <age>"`.
#
# **Example**
# Input: `age = -3`
# Expected Output: `Invalid age: -3`

# %%
def validate_age(age):
    # YOUR LOGIC HERE
    pass


# Test input
age = -3
result = validate_age(age)
print(result)

# %% [markdown]
# ### Advanced
#
# Define a custom exception `NegativeValueError(Exception)`. Write a function
# `process_numbers(numbers)` that, for each number, raises `NegativeValueError`
# if it's negative; catches this inside a loop so processing continues; and
# returns a tuple `(valid_results, error_count)` where `valid_results` is a list
# of the squares of the non-negative numbers.
#
# **Example**
# Input: `[4, -1, 3, -5, 2]`
# Expected Output: `([16, 9, 4], 2)`

# %%
class NegativeValueError(Exception):
    pass


def process_numbers(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [4, -1, 3, -5, 2]
result = process_numbers(numbers)
print(result)

# %% [markdown]
# ---
#
# ## File IO & CMD

# %% [markdown]
# ### Beginner
#
# Write a function `file_stats(filepath, content)` that first writes `content`
# to `filepath`, then reads it back and returns a tuple `(line_count, word_count)`.
#
# **Example**
# Input: `content = "hello world\nsecond line"`
# Expected Output: `(2, 4)`

# %%
def file_stats(filepath, content):
    # YOUR LOGIC HERE
    pass


# Test input
content = "hello world\nsecond line"
result = file_stats("sample.txt", content)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `run_command(cmd)` that parses a string like `"ADD 5 10"` or
# `"SUB 20 8"` and returns the numeric result. Support `ADD` and `SUB` only.
#
# **Example**
# Input: `"ADD 5 10"`
# Expected Output: `15`

# %%
def run_command(cmd):
    # YOUR LOGIC HERE
    pass


# Test input
cmd = "ADD 5 10"
result = run_command(cmd)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `parse_cmd_args(arg_string)` that parses a command-line-style
# string like `"--name John --age 30 --city Pune"` into a dictionary
# `{"name": "John", "age": "30", "city": "Pune"}`.
#
# **Example**
# Input: `"--name John --age 30"`
# Expected Output: `{'name': 'John', 'age': '30'}`

# %%
def parse_cmd_args(arg_string):
    # YOUR LOGIC HERE
    pass


# Test input
arg_string = "--name John --age 30"
result = parse_cmd_args(arg_string)
print(result)

# %% [markdown]
# ---
#
# ## Flask Request-Response

# %% [markdown]
# ### Beginner
#
# Write a function `handle_request(request)` where `request` is a dict like
# `{"method": "GET", "path": "/users"}`. Return `"List of users"` for
# `GET /users`, `"User created"` for `POST /users`, and `"Not Found"` otherwise.
#
# **Example**
# Input: `{"method": "GET", "path": "/users"}`
# Expected Output: `List of users`

# %%
def handle_request(request):
    # YOUR LOGIC HERE
    pass


# Test input
request = {"method": "GET", "path": "/users"}
result = handle_request(request)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `json_response(data, status=200)` that returns a dict shaped
# like `{"status": status, "body": data}`.
#
# **Example**
# Input: `data = {"message": "ok"}`
# Expected Output: `{'status': 200, 'body': {'message': 'ok'}}`

# %%
def json_response(data, status=200):
    # YOUR LOGIC HERE
    pass


# Test input
data = {"message": "ok"}
result = json_response(data)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `match_route(pattern, path)` that matches a Flask-style route
# pattern with a path parameter, e.g. `pattern = "/users/<id>"`,
# `path = "/users/42"`, and returns the extracted parameters as a dict:
# `{"id": "42"}`. Return `None` if the path doesn't match the pattern's shape.
#
# **Example**
# Input: `pattern = "/users/<id>", path = "/users/42"`
# Expected Output: `{'id': '42'}`

# %%
def match_route(pattern, path):
    # YOUR LOGIC HERE
    pass


# Test input
pattern = "/users/<id>"
path = "/users/42"
result = match_route(pattern, path)
print(result)

# %% [markdown]
# ---
#
# ## Flask Session

# %% [markdown]
# ### Beginner
#
# Write two functions: `login_user(session, username)` which sets
# `session['user'] = username` and returns the session, and
# `is_logged_in(session)` which returns `True` if `'user'` is in `session`,
# else `False`.
#
# **Example**
# Input: `session = {}; login_user(session, "asha")`
# Expected Output: `True` (from `is_logged_in`)

# %%
def login_user(session, username):
    # YOUR LOGIC HERE
    pass


def is_logged_in(session):
    # YOUR LOGIC HERE
    pass


# Test input
session = {}
login_user(session, "asha")
result = is_logged_in(session)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `track_visit(session)` that increments `session['visits']`
# by 1 (starting at 1 if it doesn't exist yet) and returns the new count.
#
# **Example**
# Input: `session = {}` (called twice)
# Expected Output: `1`, then `2`

# %%
def track_visit(session):
    # YOUR LOGIC HERE
    pass


# Test input
session = {}
print(track_visit(session))
print(track_visit(session))

# %% [markdown]
# ### Advanced
#
# Write a function `is_session_valid(session, max_idle_seconds, current_time)`
# where `session['last_active']` is a timestamp (in seconds). Return `True` if
# `current_time - session['last_active']` is within `max_idle_seconds`, else `False`.
#
# **Example**
# Input: `session = {"last_active": 1000}, max_idle_seconds = 300, current_time = 1200`
# Expected Output: `True`

# %%
def is_session_valid(session, max_idle_seconds, current_time):
    # YOUR LOGIC HERE
    pass


# Test input
session = {"last_active": 1000}
result = is_session_valid(session, 300, 1200)
print(result)

# %% [markdown]
# ---
#
# ## Import Statement

# %% [markdown]
# ### Beginner
#
# Write a function `mixed_imports_demo(numbers)` that uses `import statistics`
# to compute the mean, **and** `from random import choice` to pick one random
# number from the list. Return a tuple `(mean, random_pick)`.
#
# **Example**
# Input: `[10, 20, 30]`
# Expected Output: `(20.0, <one of 10/20/30>)`

# %%
import statistics
from random import choice

def mixed_imports_demo(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [10, 20, 30]
result = mixed_imports_demo(numbers)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `average_with_alias(numbers)` that computes the mean of a
# list using the `statistics` module imported **with an alias** (`import
# statistics as stats`).
#
# **Example**
# Input: `[4, 8, 12]`
# Expected Output: `8`

# %%
import statistics as stats

def average_with_alias(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [4, 8, 12]
result = average_with_alias(numbers)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `dynamic_sqrt(number)` that uses `importlib.import_module("math")`
# to import the `math` module **dynamically at runtime**, then calls its `sqrt`
# function on `number`.
#
# **Example**
# Input: `number = 81`
# Expected Output: `9.0`

# %%
import importlib

def dynamic_sqrt(number):
    # YOUR LOGIC HERE
    pass


# Test input
number = 81
result = dynamic_sqrt(number)
print(result)

# %% [markdown]
# ---
#
# ## Inheritance

# %% [markdown]
# ### Beginner
#
# Create a base class `Shape` with a method `area()` returning `0`. Create
# `Circle(Shape)` and `Square(Shape)` that override `area()` appropriately.
#
# **Example**
# Input: `Circle(radius=3)`
# Expected Output: `28.27` (approx, using pi = 3.14159, rounded to 2 decimals)

# %%
class Shape:
    def area(self):
        # YOUR LOGIC HERE
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        # YOUR LOGIC HERE
        pass


class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        # YOUR LOGIC HERE
        pass


# Test input
c = Circle(3)
result = round(c.area(), 2)
print(result)

# %% [markdown]
# ### Intermediate
#
# Create `Person` (attribute `name`), `Student(Person)` (adds `school`), and
# `GraduateStudent(Student)` (adds `thesis_title`). Give `GraduateStudent` a
# method `summary()` returning
# `"<name> studies at <school>, thesis: <thesis_title>"`.
#
# **Example**
# Input: `GraduateStudent("Rhea", "IIT Delhi", "AI Ethics")`
# Expected Output: `Rhea studies at IIT Delhi, thesis: AI Ethics`

# %%
class Person:
    def __init__(self, name):
        self.name = name


class Student(Person):
    def __init__(self, name, school):
        # YOUR LOGIC HERE
        pass


class GraduateStudent(Student):
    def __init__(self, name, school, thesis_title):
        # YOUR LOGIC HERE
        pass

    def summary(self):
        # YOUR LOGIC HERE
        pass


# Test input
g = GraduateStudent("Rhea", "IIT Delhi", "AI Ethics")
result = g.summary()
print(result)

# %% [markdown]
# ### Advanced
#
# Using multiple inheritance (mixins), create `Flyable` with method `fly()`
# returning `"flying"`, and `Swimmable` with method `swim()` returning `"swimming"`.
# Create `Duck(Flyable, Swimmable)` with a method `abilities()` that returns a
# list `[self.fly(), self.swim()]`.
#
# **Example**
# Input: `Duck().abilities()`
# Expected Output: `['flying', 'swimming']`

# %%
class Flyable:
    def fly(self):
        # YOUR LOGIC HERE
        pass


class Swimmable:
    def swim(self):
        # YOUR LOGIC HERE
        pass


class Duck(Flyable, Swimmable):
    def abilities(self):
        # YOUR LOGIC HERE
        pass


# Test input
d = Duck()
result = d.abilities()
print(result)

# %% [markdown]
# ---
#
# ## Operators

# %% [markdown]
# ### Beginner
#
# Write a function `bmi_category(weight_kg, height_m)` that computes BMI
# (`weight / height**2`) and returns `"Underweight"` (<18.5), `"Normal"`
# (18.5–24.9), `"Overweight"` (25–29.9), or `"Obese"` (30+), using arithmetic and
# comparison operators.
#
# **Example**
# Input: `weight_kg = 70, height_m = 1.75`
# Expected Output: `Normal`

# %%
def bmi_category(weight_kg, height_m):
    # YOUR LOGIC HERE
    pass


# Test input
weight_kg, height_m = 70, 1.75
result = bmi_category(weight_kg, height_m)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `is_power_of_two(n)` that returns `True` if `n` is a power of
# two, using the bitwise trick `n & (n - 1) == 0` (and handling `n <= 0`).
#
# **Example**
# Input: `n = 16`
# Expected Output: `True`

# %%
def is_power_of_two(n):
    # YOUR LOGIC HERE
    pass


# Test input
n = 16
result = is_power_of_two(n)
print(result)

# %% [markdown]
# ### Advanced
#
# Complete the `Vector` class by overloading the `+` operator (`__add__`) to add
# two vectors component-wise, and `==` (`__eq__`) to compare two vectors for
# equality.
#
# **Example**
# Input: `Vector(1, 2) + Vector(3, 4)`
# Expected Output: `(4, 6)`

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        # YOUR LOGIC HERE
        pass

    def __eq__(self, other):
        # YOUR LOGIC HERE
        pass

    def __repr__(self):
        return f"({self.x}, {self.y})"


# Test input
v1 = Vector(1, 2)
v2 = Vector(3, 4)
result = v1 + v2
print(result)

# %% [markdown]
# ---
#
# ## PDF

# %% [markdown]
# ### Beginner
#
# Write a function `pages_needed(total_lines, lines_per_page)` that returns the
# number of PDF pages needed to fit `total_lines` of text, given a fixed
# `lines_per_page` (round up for a partial page).
#
# **Example**
# Input: `total_lines = 95, lines_per_page = 40`
# Expected Output: `3`

# %%
def pages_needed(total_lines, lines_per_page):
    # YOUR LOGIC HERE
    pass


# Test input
total_lines, lines_per_page = 95, 40
result = pages_needed(total_lines, lines_per_page)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `paginate_text(lines, lines_per_page)` that takes a list of
# text lines and splits it into a list of "pages", where each page is a list of
# at most `lines_per_page` lines (simulating how a PDF generator would paginate
# content — no real PDF library needed).
#
# **Example**
# Input: `lines = ["a","b","c","d","e"], lines_per_page = 2`
# Expected Output: `[['a', 'b'], ['c', 'd'], ['e']]`

# %%
def paginate_text(lines, lines_per_page):
    # YOUR LOGIC HERE
    pass


# Test input
lines = ["a", "b", "c", "d", "e"]
lines_per_page = 2
result = paginate_text(lines, lines_per_page)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `build_toc(sections)` where `sections` is a list of
# `(title, start_page)` tuples. Return a list of formatted strings like
# `"<title> ... <page>"`, with dots padding each line to a total width of 30
# characters before the page number.
#
# **Example**
# Input: `[("Introduction", 1), ("Data Structures", 5)]`
# Expected Output: `['Introduction................1', 'Data Structures.............5']`

# %%
def build_toc(sections):
    # YOUR LOGIC HERE
    pass


# Test input
sections = [("Introduction", 1), ("Data Structures", 5)]
result = build_toc(sections)
print(result)

# %% [markdown]
# ---
#
# ## String & String Functions

# %% [markdown]
# ### Beginner
#
# Write a function `is_palindrome(text)` that returns `True` if `text` is a
# palindrome, ignoring case and spaces.
#
# **Example**
# Input: `"Nurses Run"`
# Expected Output: `True`

# %%
def is_palindrome(text):
    # YOUR LOGIC HERE
    pass


# Test input
text = "Nurses Run"
result = is_palindrome(text)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `char_frequency(text)` that returns a dictionary mapping each
# character (excluding spaces) to how many times it appears.
#
# **Example**
# Input: `"hello"`
# Expected Output: `{'h': 1, 'e': 1, 'l': 2, 'o': 1}`

# %%
def char_frequency(text):
    # YOUR LOGIC HERE
    pass


# Test input
text = "hello"
result = char_frequency(text)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `most_common_word(text)` that, ignoring case and punctuation,
# returns the most frequently occurring word in a sentence. Break ties by
# whichever word appears first.
#
# **Example**
# Input: `"The cat sat on the mat. THE cat ran."`
# Expected Output: `the`

# %%
def most_common_word(text):
    # YOUR LOGIC HERE
    pass


# Test input
text = "The cat sat on the mat. THE cat ran."
result = most_common_word(text)
print(result)

# %% [markdown]
# ---
#
# ## Types of UDF (User Defined Functions)

# %% [markdown]
# ### Beginner
#
# Write a function `sum_all(*args)` that returns the sum of any number of
# numeric arguments (a variadic / `*args` function).
#
# **Example**
# Input: `sum_all(1, 2, 3, 4)`
# Expected Output: `10`

# %%
def sum_all(*args):
    # YOUR LOGIC HERE
    pass


# Test input
result = sum_all(1, 2, 3, 4)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `get_odd_numbers(numbers)` that uses a `lambda` with
# `filter()` to return only the odd numbers from the list (an anonymous-function
# based UDF).
#
# **Example**
# Input: `[1, 2, 3, 4, 5]`
# Expected Output: `[1, 3, 5]`

# %%
def get_odd_numbers(numbers):
    # YOUR LOGIC HERE
    pass


# Test input
numbers = [1, 2, 3, 4, 5]
result = get_odd_numbers(numbers)
print(result)

# %% [markdown]
# ### Advanced
#
# Write a function `flexible_calculator(*args, **kwargs)` that sums all
# positional `args`, then multiplies the sum by `kwargs.get("factor", 1)`
# (a UDF combining both `*args` and `**kwargs`).
#
# **Example**
# Input: `flexible_calculator(1, 2, 3, factor=2)`
# Expected Output: `12`

# %%
def flexible_calculator(*args, **kwargs):
    # YOUR LOGIC HERE
    pass


# Test input
result = flexible_calculator(1, 2, 3, factor=2)
print(result)

# %% [markdown]
# ---
#
# ## UDF (User Defined Function) Basics

# %% [markdown]
# ### Beginner
#
# Write a function `simple_interest(principal, rate, time)` that returns the
# simple interest, rounded to 2 decimals: `(principal * rate * time) / 100`.
#
# **Example**
# Input: `principal = 1000, rate = 5, time = 2`
# Expected Output: `100.0`

# %%
def simple_interest(principal, rate, time):
    # YOUR LOGIC HERE
    pass


# Test input
principal, rate, time = 1000, 5, 2
result = simple_interest(principal, rate, time)
print(result)

# %% [markdown]
# ### Intermediate
#
# Write a function `factorial_recursive(n)` that computes `n!` using recursion
# (the function calling itself), not a loop.
#
# **Example**
# Input: `n = 5`
# Expected Output: `120`

# %%
def factorial_recursive(n):
    # YOUR LOGIC HERE
    pass


# Test input
n = 5
result = factorial_recursive(n)
print(result)

# %% [markdown]
# ### Advanced
#
# Using the `global` keyword, write a function `increment_counter()` that
# increments a module-level variable `counter` by 1 each time it's called, and
# returns the new value — demonstrating variable scope in UDFs.
#
# **Example**
# Input: called three times in a row
# Expected Output: `1`, then `2`, then `3`

# %%
counter = 0

def increment_counter():
    global counter
    # YOUR LOGIC HERE
    pass


# Test input
print(increment_counter())
print(increment_counter())
print(increment_counter())

# %% [markdown]
# ---
#
# ### Total Suggested Time: 3–4 hours (across all topics)
#
# **Focus:** Correct logic and understanding of each concept rather than speed.
# Every topic has one Beginner, one Intermediate, and one Advanced question —
# work through them in that order within each topic.
